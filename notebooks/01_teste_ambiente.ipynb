# %%
print("Olá Marcelo")
# Out:
# Olá Marcelo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Ambiente de Ciência de Dados OK")
# Out:
# Ambiente de Ciência de Dados OK

# %%
import sys

print("Python:", sys.version)

print("Pandas:", pd.__version__)
print("Numpy:", np.__version__)
# Out:
# Python: 3.14.6 (v3.14.6:c63aec69bd5, Jun 10 2026, 08:07:54) [Clang 21.0.0 (clang-2100.1.1.101)]
# Pandas: 3.0.5
# Numpy: 2.5.1

# %%
import sys

print(sys.executable)
# Out:
# /Users/marcelo/Project/DataScience/.venv/bin/python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

print("Ambiente Ciência de Dados funcionando!")
# Out:
# Ambiente Ciência de Dados funcionando!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sklearn

print("Tudo instalado com sucesso!")
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# Tudo instalado com sucesso!
# Pandas: 3.0.5
# NumPy: 2.5.1
# Scikit-learn: 1.9.0
