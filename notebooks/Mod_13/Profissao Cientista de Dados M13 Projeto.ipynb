# %% [markdown]
# # **MÓDULO 13**
# # Projeto - Fundamentos da Descoberta de Dados

# %% [markdown]
# Nesse projeto trabalharemos com a base de dados de produtos de um supermercado do Chile.
# A ideia é que vocês apliquem os conceitos estatísticos vistos no último módulo, mais os conceitos de visualizações de dados através de gráficos e finalizem publicando no seu github!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3 import plotly.express as px
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# Faça a leitura dos dados do arquivo CSV:
#
#
# Altere o código abaixo de acordo com seu diretório.

# %%
df = pd.read_csv("MODULO7_PROJETOFINAL_BASE_SUPERMERCADO.csv", delimiter=';')

df.head(10)
# Out:
#                                               title       Marca  Preco_Normal  \
# 0              Pack 12 un, Leche extra proteína 1 L  Loncoleche         19788
# 1   Pack 12 un, Leche chocolate receta original 1 L     Soprole         18228
# 2    Pack 12 un, Leche semidescremada chocolate 1 L     Soprole         18228
# 3     Pack 12 un, Leche semidescremada frutilla 1 L     Soprole         18228
# 4       Pack 12 un, Leche sin lactosa chocolate 1 L  Loncoleche         17988
# 5        Pack 12 un, Leche sin lactosa frutilla 1 L  Loncoleche         17988
# 6  Pack 12 un, Leche saborizada light chocolate 1 L  Loncoleche         17988
# 7         Pack 12 un, Leche saborizada frutilla 1 L       Colun         17388
# 8         Pack 12 un, Leche saborizada vainilla 1 L       Colun         17388
# 9           Pack 12 un, Leche saborizada manjar 1 L       Colun         17388
#
#    Preco_Desconto  Preco_Anterior  Desconto Categoria
# 0               0               0         0   lacteos
# ...

# %% [markdown]
# Os campos do nosso dataframe são:
#
# **Title:** Nome do produto.
#
#
# **Marca:** A marca do produto.
#
#
# **Preco_Normal:** O preço em que o produto costuma ser vendido quando não há desconto.
#
#
# **Preco_Desconto:** O preço vendido após o desconto ser aplicado.
#
#
# **Preco_Anterior:** Preço em que era comercializado o produto antes do desconto aplicado.
#
#
# **Desconto:** Total de desconto aplicado.
#
#
#
#
#
#
# As colunas que aparecem com valores 0 são para os produtos onde não tivemos descontos aplicados.
#
#
# As categorias estão em espanhol!

# %% [markdown]
# # 1 - Traga a média e a mediana dos preços - coluna Preco_Normal - por categoria de produto.
# # Identifique as categorias que parecem ter um valor de média abaixo ou acima da mediana.

# %%
import pandas as pd

# 1️⃣ Leitura do arquivo CSV
# Altere o caminho conforme seu diretório
df = pd.read_csv("MODULO7_PROJETOFINAL_BASE_SUPERMERCADO.csv")

# 2️⃣ Garantindo que a coluna Preco_Normal seja numérica
df["Preco_Normal"] = pd.to_numeric(df["Preco_Normal"], errors="coerce")

# 3️⃣ Agrupando por Categoria e calculando média e mediana
resultado = df.groupby("Categoria")["Preco_Normal"].agg(
    Media_Preco="mean",
    Mediana_Preco="median"
).reset_index()

# 4️⃣ Criando análise comparativa entre média e mediana
def analisar_distribuicao(linha):
    if linha["Media_Preco"] > linha["Mediana_Preco"]:
        return "Média acima da mediana"
    elif linha["Media_Preco"] < linha["Mediana_Preco"]:
        return "Média abaixo da mediana"
    else:
        return "Média igual à mediana"

resultado["Analise_Distribuicao"] = resultado.apply(analisar_distribuicao, axis=1)

# 5️⃣ Exibindo resultado final
print(resultado)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 import pandas as pd
#       3 # 1️⃣ Leitura do arquivo CSV
#       4 # Altere o caminho conforme seu diretório
# ----> 5 df = pd.read_csv("MODULO7_PROJETOFINAL_BASE_SUPERMERCADO.csv")
#       7 # 2️⃣ Garantindo que a coluna Preco_Normal seja numérica
#       8 df["Preco_Normal"] = pd.to_numeric(df["Preco_Normal"], errors="coerce")
#
# ...

# %%
#Seu código aqui para a mediana

# %% [markdown]
# Digite aqui as categorias:

# %% [markdown]
# # 2 - Traga o desvio padrão por categoria de produto.
# # Qual o comportamento da média e mediana nas categorias com maior desvio?

# %%
#Seu código aqui

# %% [markdown]
# Digite nesse campo o comportamento que você identificou.

# %% [markdown]
# # 3 - Plot um boxplot da distribuição do Preco_Normal para a categoria que você identificou que tem o maior desvio padrão. Como é a distribuição desses dados segundo o boxplot? Você identifica muitos outliers?

# %% [markdown]
# Dica: Para trazer apenas os dados da categoria que você deseja você pode usar o df.loc[df['Categoria'] == 'CATEGORIA ESCOLHIDA'

# %%
#Seu código aqui

# %% [markdown]
# # 4 - Plote um gráfico de barras onde temos a média de descontos por categoria.

# %%
# Seu código aqui

# %% [markdown]
# # 5 - Plote um gráfico de mapa interativo agrupando os dados por categoria, marca e trazendo a média de desconto.

# %%
# Seu código aqui
